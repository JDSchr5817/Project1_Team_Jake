# %%
import requests
import json
#from config import api_key

# %%
url = "https://api.harvardartmuseums.org/Exhibition?apikey=fb595d5f-8052-4774-99a2-fd256b149310"

# %%
print(requests.get(url))
# Out:
# <Response [200]>

# %%
response = requests.get(url).json()

# %%
print(json.dumps(response, indent = 4, sort_keys=True))
# Out:
# {
#     "info": {
#         "next": "https://api.harvardartmuseums.org/Exhibition?apikey=fb595d5f-8052-4774-99a2-fd256b149310&page=2",
#         "page": 1,
#         "pages": 474,
#         "totalrecords": 4739,
#         "totalrecordsperquery": 10
#     },
#     "records": [
#         {
#             "begindate": null,
#             "color": null,
#             "description": null,
#             "enddate": null,
#             "exhibitionid": 4176,
#             "id": 4176,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 13,
#             "textiledescription": null,
#             "title": "Balthus Exhibition",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/4176"
#         },
#         {
#             "begindate": "1791-09-01",
#             "color": null,
#             "description": null,
#             "enddate": "1791-09-30",
#             "exhibitionid": 3963,
#             "id": 3963,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 16,
#             "textiledescription": null,
#             "title": "Ouvrages de peinture, sculpture, et architecture, gravures, dessins, mod\u00e8les, etc, expos\u00e9s au Louvre par ordre de l'Assembl\u00e9e nationale, au mois de septembre 1791, l'an Ille de la Libert\u00e9",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3963"
#         },
#         {
#             "begindate": "1809",
#             "color": null,
#             "description": null,
#             "enddate": "1809",
#             "exhibitionid": 3992,
#             "id": 3992,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 20,
#             "textiledescription": null,
#             "title": "Exhibition of Paintings in Fresco, Poetical and Historical Inventions",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3992"
#         },
#         {
#             "begindate": "1833",
#             "color": null,
#             "description": null,
#             "enddate": "1833",
#             "exhibitionid": 4244,
#             "id": 4244,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 43,
#             "textiledescription": null,
#             "title": "Probably Boston Athenaeum",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/4244"
#         },
#         {
#             "begindate": "1867-12-21",
#             "color": null,
#             "description": null,
#             "enddate": "1868-03-31",
#             "exhibitionid": 3870,
#             "id": 3870,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 104,
#             "textiledescription": null,
#             "title": "Winter Exhibition of the American Society of Painters in Water Colors",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3870"
#         },
#         {
#             "begindate": "1878-01-01",
#             "color": null,
#             "description": null,
#             "enddate": "1878-12-31",
#             "exhibitionid": 3849,
#             "id": 3849,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 145,
#             "textiledescription": null,
#             "title": "Notes by Mr. Ruskin. Part I. On His Drawings by the Late J.M.W. Turner, R.A. Part II. On His Own Handiwork Illustrative of Turner",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3849"
#         },
#         {
#             "begindate": "1879-05-01",
#             "color": null,
#             "description": null,
#             "enddate": "1879-06-30",
#             "exhibitionid": 3966,
#             "id": 3966,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 157,
#             "textiledescription": null,
#             "title": "Exposition de dessins de ma\u00eetres anciens",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3966"
#         },
#         {
#             "begindate": "1885",
#             "color": null,
#             "description": null,
#             "enddate": "1885",
#             "exhibitionid": 3888,
#             "id": 3888,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 195,
#             "textiledescription": null,
#             "title": "Exhibition of Works by Henry Roderick Newman",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3888"
#         },
#         {
#             "begindate": "1892-01-01",
#             "color": null,
#             "description": null,
#             "enddate": "1892-12-31",
#             "exhibitionid": 1305,
#             "id": 1305,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 245,
#             "textiledescription": null,
#             "title": "Sixth Annual Loan Exhibition: American Paintings Never Before Exhibited",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/1305"
#         },
#         {
#             "begindate": "1892-04-15",
#             "color": null,
#             "description": null,
#             "enddate": "1892-04-30",
#             "exhibitionid": 3438,
#             "id": 3438,
#             "lastupdate": "2021-04-28T04:27:18-0400",
#             "shortdescription": null,
#             "temporalorder": 251,
#             "textiledescription": null,
#             "title": "Soci\u00e9t\u00e9 de peintres-graveurs fran\u00e7ais: Quatri\u00e8me Exposition",
#             "url": "https://www.harvardartmuseums.org/visit/exhibitions/3438"
#         }
#     ]
# }
